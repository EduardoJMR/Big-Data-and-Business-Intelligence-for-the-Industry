# %%
#Series temporales

# %%
import pandas as pnd
pnd.to_datetime('2022-04-05 1:25pm')
# Out:
# Timestamp('2022-04-05 13:25:00')

# %%
pnd.to_datetime('9/8/1993')
# Out:
# Timestamp('1993-09-08 00:00:00')

# %%
pnd.to_datetime('9/8/1993',dayfirst=True)
# Out:
# Timestamp('1993-08-09 00:00:00')

# %%
pnd.to_datetime(['2019-07-18','9/8/1993','12/15/2021'])
# Out:
# DatetimeIndex(['2019-07-18', '1993-09-08', '2021-12-15'], dtype='datetime64[ns]', freq=None)

# %%
pnd.to_datetime(['18/07/19','9/8/93','15/03/22'], format='%d/%m/%y')
# Out:
# DatetimeIndex(['2019-07-18', '1993-08-09', '2022-03-15'], dtype='datetime64[ns]', freq=None)

# %%
#Creacion de un DateFrame de Series Temporales
opsd_dia=pnd.read_csv('opsd_germany_daily.csv')
opsd_dia.shape
# Out:
# (4383, 5)

# %%
opsd_dia.head(4)
# Out:
#          Date  Consumption  Wind  Solar  Wind+Solar
# 0  2006-01-01     1069.184   NaN    NaN         NaN
# 1  2006-01-02     1380.521   NaN    NaN         NaN
# 2  2006-01-03     1442.533   NaN    NaN         NaN
# 3  2006-01-04     1457.217   NaN    NaN         NaN

# %%
opsd_dia.tail(4)
# Out:
#             Date  Consumption     Wind   Solar  Wind+Solar
# 4379  2017-12-28   1299.86398  506.424  14.162     520.586
# 4380  2017-12-29   1295.08753  584.277  29.854     614.131
# 4381  2017-12-30   1215.44897  721.247   7.467     728.714
# 4382  2017-12-31   1107.11488  721.176  19.980     741.156

# %%
opsd_dia=pnd.read_csv('opsd_germany_daily.csv',index_col=0,parse_dates=True)
opsd_dia.index
# Out:
# DatetimeIndex(['2006-01-01', '2006-01-02', '2006-01-03', '2006-01-04',
#                '2006-01-05', '2006-01-06', '2006-01-07', '2006-01-08',
#                '2006-01-09', '2006-01-10',
#                ...
#                '2017-12-22', '2017-12-23', '2017-12-24', '2017-12-25',
#                '2017-12-26', '2017-12-27', '2017-12-28', '2017-12-29',
#                '2017-12-30', '2017-12-31'],
#               dtype='datetime64[ns]', name='Date', length=4383, freq=None)

# %%
opsd_dia['Año']=opsd_dia.index.year
opsd_dia['Mes']=opsd_dia.index.month
opsd_dia['Dia']=opsd_dia.index.day_name()
opsd_dia.sample(8,random_state=0)
# Out:
#             Consumption    Wind    Solar  Wind+Solar   Año  Mes       Dia
# Date
# 2008-08-23     1152.011     NaN      NaN         NaN  2008    8  Saturday
# 2013-08-08     1291.984  79.666   93.371     173.037  2013    8  Thursday
# 2009-08-27     1281.057     NaN      NaN         NaN  2009    8  Thursday
# 2015-10-02     1391.050  81.229  160.641     241.870  2015   10    Friday
# 2009-06-02     1201.522     NaN      NaN         NaN  2009    6   Tuesday
# 2015-02-03     1639.260  97.155   27.530     124.685  2015    2   Tuesday
# 2012-05-28      988.853  36.311  151.315     187.626  2012    5    Monday
# 2011-07-10     1023.542  22.717      NaN         NaN  2011    7    Sunday

# %%
opsd_dia.loc['2017-07-17']
# Out:
# Consumption    1350.745
# Wind              98.54
# Solar           177.551
# Wind+Solar      276.091
# Año                2017
# Mes                   7
# Dia              Monday
# Name: 2017-07-17 00:00:00, dtype: object

# %%
opsd_dia.loc['2013-08-15':'2013-08-20']
# Out:
#             Consumption     Wind    Solar  Wind+Solar   Año  Mes       Dia
# Date
# 2013-08-15     1230.894   41.649  161.266     202.915  2013    8  Thursday
# 2013-08-16     1235.737   67.690  177.432     245.122  2013    8    Friday
# 2013-08-17     1064.704   50.787  150.753     201.540  2013    8  Saturday
# 2013-08-18     1003.820  139.001  104.760     243.761  2013    8    Sunday
# 2013-08-19     1279.894   65.016   71.198     136.214  2013    8    Monday
# 2013-08-20     1262.606   43.807  112.443     156.250  2013    8   Tuesday

# %%
opsd_dia.loc['2017-12']
# Out:
#             Consumption     Wind   Solar  Wind+Solar   Año  Mes        Dia
# Date
# 2017-12-01   1592.96187   52.323  19.266      71.589  2017   12     Friday
# 2017-12-02   1391.85405  126.274  16.459     142.733  2017   12   Saturday
# 2017-12-03   1330.26226  387.490  12.411     399.901  2017   12     Sunday
# 2017-12-04   1620.97758  479.798  10.747     490.545  2017   12     Monday
# 2017-12-05   1643.72307  611.488  10.953     622.441  2017   12    Tuesday
# 2017-12-06   1639.08265  632.501   7.618     640.119  2017   12  Wednesday
# 2017-12-07   1628.47979  743.725  42.994     786.719  2017   12   Thursday
# 2017-12-08   1618.05658  652.830  20.504     673.334  2017   12     Friday
# 2017-12-09   1415.34531  712.317  12.344     724.661  2017   12   Saturday
# 2017-12-10   1318.10964  622.944   9.922     632.866  2017   12     Sunday
# 2017-12-11   1614.15862  415.109   5.669     420.778  2017   12     Monday
# 2017-12-12   1647.36346  590.101  13.250     603.351  2017   12    Tuesday
# 2017-12-13   1651.90418  721.540  36.880     758.420  2017   12  Wednesday
# 2017-12-14   1636.54375  666.438  21.030     687.468  2017   12   Thursday
# 2017-12-15   1576.93197  176.418  21.653     198.071  2017   12     Friday
# 2017-12-16   1382.87708  277.391  15.904     293.295  2017   12   Saturday
# 2017-12-17   1297.21916  250.726  12.620     263.346  2017   12     Sunday
# 2017-12-18   1578.69079  134.843  15.897     150.740  2017   12     Monday
# 2017-12-19   1586.48230   99.098   8.793     107.891  2017   12    Tuesday
# 2017-12-20   1559.68569   90.880   8.799      99.679  2017   12  Wednesday
# 2017-12-21   1520.37206  259.039   7.313     266.352  2017   12   Thursday
# 2017-12-22   1423.23782  228.773  10.065     238.838  2017   12     Friday
# 2017-12-23   1272.17085  748.074   8.450     756.524  2017   12   Saturday
# 2017-12-24   1141.75730  812.422   9.949     822.371  2017   12     Sunday
# 2017-12-25   1111.28338  587.810  15.765     603.575  2017   12     Monday
# 2017-12-26   1130.11683  717.453  30.923     748.376  2017   12    Tuesday
# 2017-12-27   1263.94091  394.507  16.530     411.037  2017   12  Wednesday
# 2017-12-28   1299.86398  506.424  14.162     520.586  2017   12   Thursday
# 2017-12-29   1295.08753  584.277  29.854     614.131  2017   12     Friday
# 2017-12-30   1215.44897  721.247   7.467     728.714  2017   12   Saturday
# 2017-12-31   1107.11488  721.176  19.980     741.156  2017   12     Sunday

# %%
#Visualizacion de Datos de Series Temporales
import matplotlib.pyplot as mplt #Esta funcion es utilizada para mostrar los graficos

# %%
import seaborn as sbn
sbn.set(rc={'figure.figsize':(10,5)})

# %%
opsd_dia['Consumption'].plot(Linewidth=0.1)
# Out:
# C:\Users\eduma\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:711: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   return ax.plot(*args, **kwds)
# <AxesSubplot:xlabel='Date'>

# %%
col_graf=['Consumption','Solar','Wind']
ejes=opsd_dia[col_graf].plot(marker='.',alpha=0.1,linestyle='None',figsize=(10,10),subplots=True)
for eje in ejes:
    eje.set_ylabel('Consumo Diario (GWh)')

# %%
eje=opsd_dia.loc['2016','Consumption'].plot()
eje.set_ylabel('Consumo Diario (GWh)')
# Out:
# Text(0, 0.5, 'Consumo Diario (GWh)')

# %%
eje=opsd_dia.loc['2016-01':'2016-02','Consumption'].plot(marker='o',linestyle='-')
eje.set_ylabel('Consumo Diario (GWh)')
# Out:
# Text(0, 0.5, 'Consumo Diario (GWh)')

# %%
fig,ejes=mplt.subplots(3,1,figsize=(11,10),sharex=True)
for nombre, eje in zip(['Consumption','Solar','Wind'],ejes):
    sbn.boxplot(data=opsd_dia,x=opsd_dia.index.month,y=nombre,ax=eje)
    eje.set_title(nombre)
    if eje != ejes[-1]:
        eje.set_xlabel('')

# %%
sbn.boxplot(data=opsd_dia, x=opsd_dia.index.day_name(),y='Consumption')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Consumption'>

# %%
pnd.date_range('2015-09-15','2015-09-20',freq='D')
# Out:
# DatetimeIndex(['2015-09-15', '2015-09-16', '2015-09-17', '2015-09-18',
#                '2015-09-19', '2015-09-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
pnd.date_range('2005-10-15',periods=8,freq='H')
# Out:
# DatetimeIndex(['2005-10-15 00:00:00', '2005-10-15 01:00:00',
#                '2005-10-15 02:00:00', '2005-10-15 03:00:00',
#                '2005-10-15 04:00:00', '2005-10-15 05:00:00',
#                '2005-10-15 06:00:00', '2005-10-15 07:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
opsd_dia.index
# Out:
# DatetimeIndex(['2006-01-01', '2006-01-02', '2006-01-03', '2006-01-04',
#                '2006-01-05', '2006-01-06', '2006-01-07', '2006-01-08',
#                '2006-01-09', '2006-01-10',
#                ...
#                '2017-12-22', '2017-12-23', '2017-12-24', '2017-12-25',
#                '2017-12-26', '2017-12-27', '2017-12-28', '2017-12-29',
#                '2017-12-30', '2017-12-31'],
#               dtype='datetime64[ns]', name='Date', length=4383, freq=None)

# %%
muestra_tiempo=pnd.to_datetime(['2010-03-02','2010-03-04','2010-03-06'])
muestra_consumo=opsd_dia.loc[muestra_tiempo,['Consumption']].copy()
muestra_consumo
# Out:
#             Consumption
# Date
# 2010-03-02     1572.645
# 2010-03-04     1548.184
# 2010-03-06     1310.888

# %%
frec_consumo=muestra_consumo.asfreq('D')
frec_consumo['Consumption-Datos llenos']=muestra_consumo.asfreq('D',method='ffill')
frec_consumo
# Out:
#             Consumption  Consumption-Datos llenos
# Date
# 2010-03-02     1572.645                  1572.645
# 2010-03-03          NaN                  1572.645
# 2010-03-04     1548.184                  1548.184
# 2010-03-05          NaN                  1548.184
# 2010-03-06     1310.888                  1310.888

# %%
#Remuestreo
columnas=['Consumption','Wind','Solar','Wind+Solar']
media_opsd_semanal=opsd_dia[columnas].resample('W').mean()
media_opsd_semanal.head(3)
# Out:
#             Consumption  Wind  Solar  Wind+Solar
# Date
# 2006-01-01  1069.184000   NaN    NaN         NaN
# 2006-01-08  1381.300143   NaN    NaN         NaN
# 2006-01-15  1486.730286   NaN    NaN         NaN

# %%
opsd_dia.shape[0]
# Out:
# 4383

# %%
media_opsd_semanal.shape[0]
# Out:
# 627

# %%
inicio,final='2015-06','2015-12'
fig,eje=mplt.subplots()
eje.plot(opsd_dia.loc[inicio:final,'Solar'],marker='.',linestyle='-',linewidth=0.5,label='Diario')
eje.plot(media_opsd_semanal.loc[inicio:final,'Solar'],marker='o',markersize=5,label='Semanal')
eje.set_ylabel('Producción Solar (GWh)')
eje.legend()

# %%
opsd_mensual=opsd_dia[columnas].resample('M').sum(min_count=28)
opsd_mensual.head(4)
# Out:
#             Consumption  Wind  Solar  Wind+Solar
# Date
# 2006-01-31    45304.704   NaN    NaN         NaN
# 2006-02-28    41078.993   NaN    NaN         NaN
# 2006-03-31    43978.124   NaN    NaN         NaN
# 2006-04-30    38251.767   NaN    NaN         NaN

# %%
fig,eje=mplt.subplots()
eje.plot(opsd_mensual['Consumption'],color='black',label='Consumo')
opsd_mensual[['Wind','Solar']].plot.area(ax=eje,linewidth=0)
eje.legend()
eje.set_ylabel('Total Mensual (GWh)')
# Out:
# Text(0, 0.5, 'Total Mensual (GWh)')

# %%
opsd_anual=opsd_dia[columnas].resample('A').sum(min_count=360)
opsd_anual=opsd_anual.set_index(opsd_anual.index.year)
opsd_anual.index.name='Año'
opsd_anual['Wind+Solar/Consumo']=opsd_anual['Wind+Solar']/opsd_anual['Consumption']
opsd_anual.tail(4)
# Out:
#        Consumption        Wind      Solar  Wind+Solar  Wind+Solar/Consumo
# Año
# 2014  504164.82100   51107.672  32498.307   83370.502            0.165364
# 2015  505264.56300   77468.994  34907.138  112376.132            0.222410
# 2016  505927.35400   77008.126  34562.824  111570.950            0.220528
# 2017  504736.36939  102667.365  35882.643  138550.008            0.274500

# %%
#El grafico comienza en 2012, ya que antes de 2012 no habia produccion de energia solar
eje=opsd_anual.loc[2012:,'Wind+Solar/Consumo'].plot.bar()
eje.set_ylabel('Fraccion')
eje.set_ylim(0,0.5)
eje.set_title('Carga de Consumo Anual Total Wind+Solar')
# Out:
# Text(0.5, 1.0, 'Carga de Consumo Anual Total Wind+Solar')

# %%
#Ventanas deslizantes
opsd_7d=opsd_dia[columnas].rolling(7,center=True).mean()
opsd_7d.head(5)
# Out:
#             Consumption  Wind  Solar  Wind+Solar
# Date
# 2006-01-01          NaN   NaN    NaN         NaN
# 2006-01-02          NaN   NaN    NaN         NaN
# 2006-01-03          NaN   NaN    NaN         NaN
# 2006-01-04  1361.471429   NaN    NaN         NaN
# 2006-01-05  1381.300143   NaN    NaN         NaN

# %%
import pandas as pnd
import matplotlib.pyplot as mplt
import seaborn as sbn
sbn.set(rc={'figure.figsize':(10,5)})
opsd_dia=pnd.read_csv('opsd_germany_daily.csv',index_col=0,parse_dates=True)
opsd_7d=opsd_dia[columnas].rolling(7,center=True).mean()
inicio,final='2017-06','2017-12'
fig,eje=mplt.subplots()
eje.plot(opsd_dia.loc[inicio:final,'Solar'],marker='.',linestyle='-',linewidth=0.5,label='Diario')
eje.plot(media_opsd_semanal.loc[inicio:final,'Solar'],marker='o',linestyle='-',linewidth=0.5,label='Semanal')
eje.plot(opsd_7d.loc[inicio:final,'Solar'],marker='.',linestyle='-',linewidth=.5,label='Media Deslizante de 7 Dias')
eje.set_ylabel('Produccion Solar (GWh)')
eje.legend()

# %%
#Tendencias
#El argumento mini_periods=360 toma en cuenta algunos dias faltantes en las medias de energia solar
#y eólica
opsd_365d= opsd_dia[columnas].rolling(window=365,center=True,min_periods=360).mean()

# %%
#El grafico de esto sería
import pandas as pnd
import matplotlib.pyplot as mplt
import seaborn as sbn
sbn.set(rc={'figure.figsize':(10,5)})
opsd_dia=pnd.read_csv('opsd_germany_daily.csv', index_col=0,parse_dates=True)
opsd_365d=opsd_dia[columnas].rolling(7,center=True).mean()
opsd_7d=opsd_dia[columnas].rolling(7,center=True).mean()
fig,eje=mplt.subplots()
eje.plot(opsd_dia['Consumption'],marker='.',markersize=2,color='0.6',linestyle='None',label='Diario')
eje.plot(opsd_7d['Consumption'],linewidth=2,label='Media deslizante semanal')
eje.plot(opsd_365d['Consumption'],color='0.2',linewidth=3,label='Tendencia(Media deslizante anual)')
eje.legend()
eje.set_xlabel('Año')
eje.set_ylabel('Consumo (GWh)')
eje.set_title('Tendencias en el Consumo Electrico')
# Out:
# Text(0.5, 1.0, 'Tendencias en el Consumo Electrico')

# %%
fig,eje=mplt.subplots()
for i in ['Wind','Solar','Wind+Solar']:
    eje.plot(opsd_365d[i],label=i)
    eje.set_ylim(0,500)
    eje.legend()
    eje.set_ylabel('Produccion (GWh)')
    eje.set_title('Tendencias en la producción de electricidad')
